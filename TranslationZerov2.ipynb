# %% [markdown]
# #PyTorch
# #神經網路翻譯系統v2
# #序列對序列(Seq2Seq)
# #By Andrew Huang

# %% [markdown]
# #安裝Spacy Library

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download de_core_news_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.7.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.4 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# Collecting de_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.2.5/de_core_news_sm-2.2.5.tar.gz (14.9 MB)
#      |████████████████████████████████| 14.9 MB 7.1 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from de_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (4.62.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->de_core_news_sm==2.2.5) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.4)
# Building wheels for collected packages: de-core-news-sm
#   Building wheel for de-core-news-sm (setup.py) ... done
#   Created wheel for de-core-news-sm: filename=de_core_news_sm-2.2.5-py3-none-any.whl size=14907055 sha256=1d9fce7c47bf6f993ca0e8bbdf2dde9a2c5d374cdf0887c00f6d0efd9c2115a1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0ne5rtkh/wheels/00/66/69/cb6c921610087d2cab339062345098e30a5ceb665360e7b32a
# Successfully built de-core-news-sm
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('de_core_news_sm')

# %% [markdown]
# #匯入必要的程式庫

# %%
import torch
import torchtext
import numpy
import en_core_web_sm
import de_core_news_sm
from google.colab import drive

# %% [markdown]
# # 掛載雲端硬碟

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #處理資料

# %%
en_nlp = en_core_web_sm.load()
de_nlp = de_core_news_sm.load()

def token_pair_src(text):
  text = str(text).strip()
  return [token_text.text for token_text in en_nlp.tokenizer(text)]

def token_pair_dst(text):
  text = str(text).strip()
  return [token_text.text for token_text in de_nlp.tokenizer(text)]

def load_dataset(root="/content/drive/MyDrive/PythonProject/TranslationZero", pair_lang=(".en", ".de"), batch_size=200, seq_len = 50):
    
  TEXT_SRC = torchtext.legacy.data.Field(
      unk_token="<unk>",
      pad_token="<pad>",
      eos_token="<eos>",
      init_token="<sos>",
      tokenize=token_pair_src,
      sequential=True,
      use_vocab=True,
      fix_length=seq_len)
    
  TEXT_DST = torchtext.legacy.data.Field(
      unk_token="<unk>",
      pad_token="<pad>",
      eos_token="<eos>",
      init_token="<sos>",
      tokenize=token_pair_dst,
      sequential=True,
      use_vocab=True,
      fix_length=seq_len)   
    
  pair_field = (TEXT_SRC, TEXT_DST)

  train_data, val_data, test_data = torchtext.legacy.datasets.Multi30k.splits(exts=pair_lang, fields=pair_field, root=root)

  TEXT_SRC.build_vocab(train_data, val_data, test_data, max_size=30000)
  TEXT_DST.build_vocab(train_data, val_data, test_data, max_size=30000)        
    
  train_iterator = torchtext.legacy.data.Iterator(
      dataset=train_data, 
      batch_size=batch_size, 
      shuffle=True)
  val_iterator = torchtext.legacy.data.Iterator(
      dataset=val_data, 
      batch_size=batch_size, 
      shuffle=True)
  test_iterator = torchtext.legacy.data.Iterator(
      dataset=test_data, 
      batch_size=batch_size, 
      shuffle=True)
  return train_iterator, val_iterator, test_iterator, TEXT_SRC.vocab, TEXT_DST.vocab

batch_size = 200
seq_len = 30
hidden_size = 256
num_layer = 2
epoch = 10
train_set, val_set, test_set, src_vocab, dst_vocab = load_dataset(batch_size=batch_size, seq_len=seq_len)
src_vocab_len = len(src_vocab)
dst_vocab_len = len(dst_vocab)

# %% [markdown]
# #建置EncoderNetwork Model

# %%
class EncoderNet(torch.nn.Module):

  def __init__(self, vocab_size, hidden_size, num_layer=1):
    super(EncoderNet, self).__init__()
    self.embedding_layer = torch.nn.Embedding(vocab_size, hidden_size)
    self.encoder_layer = torch.nn.TransformerEncoder(
      torch.nn.TransformerEncoderLayer(hidden_size, nhead=8), num_layers=num_layer)
  
  def forward(self, inputs):
    outputs = self.embedding_layer(inputs)
    outputs = self.encoder_layer(outputs)
    return outputs

# %% [markdown]
# #建置DecoderNetwork Model

# %%
class DecoderNet(torch.nn.Module):

  def __init__(self, vocab_size, hidden_size, num_layer=1):
    super(DecoderNet, self).__init__()
    self.embedding_layer = torch.nn.Embedding(vocab_size, hidden_size)
    self.decoder_layer = torch.nn.TransformerDecoder(
      torch.nn.TransformerDecoderLayer(hidden_size, nhead=8), num_layers=num_layer)
    self.fc_layer = torch.nn.Linear(hidden_size, vocab_size)

  def forward(self, inputs, memory):
    inputs = inputs.unsqueeze(0)
    outputs = self.embedding_layer(inputs)
    outputs = self.decoder_layer(outputs, memory)
    outputs = self.fc_layer(outputs)
    outputs = outputs.squeeze(0)
    return outputs

# %% [markdown]
# #建置Seq2Seq Model

# %%
class Seq2Seq(torch.nn.Module):

  def __init__(self, src_vocab_size, dst_vocab_size, hidden_size, num_layer=1):
    super(Seq2Seq, self).__init__()
    self.encoder = EncoderNet(src_vocab_size, hidden_size, num_layer)
    self.decoder = DecoderNet(dst_vocab_size, hidden_size, num_layer)

  def forward(self, src_inputs, dst_inputs):
    enc_outputs = self.encoder(src_inputs)
    outputs = torch.zeros(seq_len, batch_size, dst_vocab_len)
    if torch.cuda.device_count() > 0:
      outputs = outputs.cuda()
    target = dst_inputs[0]
    enc = enc_outputs[0].unsqueeze(0)
    for i in range(1, seq_len):
      output = self.decoder(target, enc)
      outputs[i] = output
      target = dst_inputs[i]
      enc = enc_outputs[i].unsqueeze(0)
    return outputs
  
  def prediction(self, x, vocab, seq_len = 30):
    result = ['<sos>']
    with torch.no_grad():
      enc_outputs = self.encoder(x)
      sos_token = [vocab.stoi[result[0]]]
      target = torch.from_numpy(numpy.array(sos_token))
      if torch.cuda.device_count() > 0:
        target = target.cuda()
      for i in range(seq_len):
        outputs = self.decoder(target, enc_outputs[i].unsqueeze(0))
        topi = outputs.argmax(1)
        if vocab.itos[topi.item()] == "<eos>":
          result.append(vocab.itos[topi.item()]) 
          break
        else:
          result.append(vocab.itos[topi.item()]) 
        target = topi
    return result

# %% [markdown]
# #開始訓練

# %%
seq2seq = Seq2Seq(src_vocab_len, dst_vocab_len, hidden_size, num_layer)
if torch.cuda.device_count() > 0:
  seq2seq = seq2seq.cuda()
optim = torch.optim.Adam(seq2seq.parameters(), lr = 0.001)
loss_fn = torch.nn.CrossEntropyLoss()

for i in range(epoch):
  for iters, data in enumerate(train_set, 0):
    src_inputs = data.src.long()
    dst_inputs = data.trg.long()
    if torch.cuda.device_count() > 0:
      src_inputs = src_inputs.cuda()
      dst_inputs = dst_inputs.cuda()
    outputs = seq2seq(src_inputs, dst_inputs)
    loss = loss_fn(outputs.reshape(-1, outputs.shape[2]), dst_inputs.reshape(-1))
 
    optim.zero_grad()
    loss.backward()
    optim.step()

    if iters % 10 == 0:
      print("[+] Epoch: [%d/%d] Loss: %.4f" % (i+1, epoch, loss.item()))
      print(seq2seq.prediction(src_inputs[:, 0].unsqueeze(1), dst_vocab, seq_len))

torch.save(seq2seq.state_dict(), "/content/drive/MyDrive/PythonProject/TranslationZero/seq2seq_modelv2.pth")
# Out:
# [+] Epoch: [1/10] Loss: 10.4038
# ['<sos>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# [+] Epoch: [1/10] Loss: 3.2960
# ['<sos>', 'Ein', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# [+] Epoch: [1/10] Loss: 2.8853
# ['<sos>', 'Ein', 'Mann', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.6617
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'Mann', 'in', 'einem', 'in', 'einem', 'Mann', 'in', 'einem', 'Mann', 'in', 'einem', '<eos>']
# [+] Epoch: [1/10] Loss: 2.4463
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'auf', 'einem', 'auf', 'einem', 'auf', 'einem', 'roten', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.5248
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'roten', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.5215
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'roten', 'und', 'ein', 'Foto', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.4681
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'weißen', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.3585
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'blauen', 'Hemd', 'und', 'ein', 'Foto', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.3733
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'weißen', 'Hemd', 'und', 'ein', 'Mann', 'in', 'einem', 'roten', 'Hemd', 'und', 'ein', 'Mann', 'in', 'einem', 'schwarzen', 'Hemd', 'und', 'eine', 'Frau', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.1562
# ['<sos>', 'Ein', 'Junge', 'in', 'der', 'Hand', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.1998
# ['<sos>', 'Eine', 'Gruppe', 'von', 'einem', 'weißen', 'Hemd', 'mit', 'einem', 'weißen', 'Hemd', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.2580
# ['<sos>', 'Zwei', 'Männer', 'spielen', 'auf', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.1497
# ['<sos>', 'Zwei', 'Männer', 'in', 'der', 'Straße', '.', '<eos>']
# [+] Epoch: [1/10] Loss: 2.1104
# ['<sos>', 'Eine', 'Frau', 'in', 'einem', 'blauen', 'Kleid', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.1066
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'blauen', 'Hemd', 'und', 'ein', 'anderer', 'Mann', 'mit', 'einem', 'Mann', 'mit', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.1074
# ['<sos>', 'Zwei', 'Männer', 'stehen', 'auf', 'dem', 'Boden', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.0958
# ['<sos>', 'Eine', 'Gruppe', 'von', 'Menschen', ',', 'während', 'sie', 'auf', 'einem', 'großen', 'Welle', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.0283
# ['<sos>', 'Ein', 'Mann', 'auf', 'einem', 'Fahrrad', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.0584
# ['<sos>', 'Eine', 'Person', 'in', 'einem', 'weißen', 'Trikot', ',', 'die', 'Straße', 'entlang', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.0323
# ['<sos>', 'Ein', 'kleines', 'Kind', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 1.9627
# ['<sos>', 'Eine', 'Person', 'fährt', 'ein', 'Foto', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.0445
# ['<sos>', 'Eine', 'Frau', 'mit', 'einem', 'Tisch', 'mit', 'einem', 'Tisch', 'mit', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.0177
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'roten', 'Oberteil', 'und', 'einem', 'roten', 'Oberteil', 'und', 'einem', 'roten', 'Oberteil', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 2.0175
# ['<sos>', 'Ein', 'Mann', 'macht', 'einen', 'Ball', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 1.8749
# ['<sos>', 'Zwei', 'Mädchen', 'in', 'einem', 'Feld', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 1.9166
# ['<sos>', 'Ein', 'Mann', 'auf', 'einem', 'Fahrrad', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 1.8579
# ['<sos>', 'Ein', 'Paar', 'geht', 'im', 'Hintergrund', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 1.8962
# ['<sos>', 'Zwei', 'Personen', 'sitzen', 'auf', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [2/10] Loss: 1.8503
# ['<sos>', 'Ein', 'kleines', 'Mädchen', 'spielt', 'auf', 'einem', 'Feld', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.8691
# ['<sos>', 'Ein', 'Mann', 'mittleren', 'Alters', 'in', 'einem', 'weißen', 'Oberteil', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.7466
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'Mann', 'mit', 'einem', 'anderen', 'Mann', 'mit', 'dem', 'Kopf', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.7611
# ['<sos>', 'Jemand', 'fährt', 'auf', 'einem', 'Fahrrad', 'fährt', 'auf', 'einem', 'Feld', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.7167
# ['<sos>', 'Ein', 'Mädchen', 'mit', 'einem', 'Tisch', 'und', 'ein', 'Mädchen', 'mit', 'einem', 'Baum', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.8452
# ['<sos>', 'Eine', 'Menschenmenge', 'steht', 'vor', 'einem', 'roten', 'Hemd', 'steht', 'vor', 'einer', 'Brille', 'steht', 'mit', 'einem', 'roten', 'Jacke', 'steht', 'vor', 'einem', 'Gebäude', 'mit', 'Brille', 'steht', 'vor', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.7077
# ['<sos>', 'Ein', 'Mann', 'und', 'eine', 'Frau', 'und', 'eine', 'Frau', ',', 'der', 'eine', 'Frau', ',', 'der', 'Hand', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.7972
# ['<sos>', 'Zwei', 'junge', 'Frau', 'in', 'einem', 'großen', 'Gebäude', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.8859
# ['<sos>', 'Zwei', 'junge', 'Männer', 'mit', 'einem', 'Tisch', ',', 'die', 'in', 'einem', 'Markt', 'in', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.7430
# ['<sos>', 'Eine', 'Frau', 'in', 'einem', 'roten', 'Kleid', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.9301
# ['<sos>', 'Eine', 'Frau', 'sitzen', 'in', 'einem', 'Mann', ',', 'die', 'ein', 'Mann', 'sitzt', 'in', 'einem', 'Mann', 'sitzt', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.7465
# ['<sos>', 'Ein', 'Mann', 'hält', 'ein', 'Baby', 'hält', 'einen', 'Tisch', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.6979
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'blauen', 'Jacke', 'mit', 'einem', 'blauen', 'Jacke', 'mit', 'seinem', 'Fahrrad', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.6898
# ['<sos>', 'Ein', 'Mann', 'steht', 'auf', 'einem', 'Mann', 'mit', 'einem', 'anderen', 'Mann', ',', 'der', 'Hand', ',', 'während', 'er', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.6942
# ['<sos>', 'Ein', 'Baby', 'an', 'einem', 'Markt', '.', '<eos>']
# [+] Epoch: [3/10] Loss: 1.8000
# ['<sos>', 'Fünf', 'Personen', 'sitzen', 'an', 'einem', 'Restaurant', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6663
# ['<sos>', 'Ein', 'Junge', 'und', 'spielt', 'ein', 'Mädchen', ',', 'der', 'ein', 'Mädchen', ',', 'und', 'ein', 'Junge', 'sitzt', 'auf', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6510
# ['<sos>', 'Zwei', 'Männer', 'mittleren', 'Alters', 'stehen', 'stehen', 'vor', 'einem', 'großen', 'Raum', 'stehen', 'vor', 'einem', 'Gebäude', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6490
# ['<sos>', 'Ein', 'kleines', 'Mädchen', 'und', 'fährt', 'ein', 'kleines', 'Mädchen', 'und', 'ein', 'kleines', 'Kind', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6377
# ['<sos>', 'Eine', 'Frau', 'auf', 'einem', 'Schild', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6375
# ['<sos>', 'Ein', 'Mann', 'springt', 'von', 'einem', 'Gewässer', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6508
# ['<sos>', 'Eine', 'Frau', 'sitzt', 'auf', 'dem', 'Boden', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.5499
# ['<sos>', 'Zwei', 'Radfahrer', 'fahren', 'mit', 'dem', 'Feld', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.5782
# ['<sos>', 'Ein', 'Fotograf', 'mit', 'dem', 'Wasser', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6251
# ['<sos>', 'Ein', 'schwarz-weißer', 'Hund', 'spielt', 'mit', 'einem', 'Hof', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6638
# ['<sos>', 'Zwei', 'Personen', ',', 'die', 'Straße', 'entlang', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.5388
# ['<sos>', 'Zwei', 'Polizisten', 'in', 'einem', 'Raum', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.5824
# ['<sos>', 'Ein', 'Mann', 'und', 'ein', 'Junge', 'und', 'ein', 'Mann', 'auf', 'einer', 'Veranda', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.6184
# ['<sos>', 'Ein', 'Mann', 'in', 'schwarzem', 'Hemd', ',', 'der', 'andere', 'Person', 'in', 'den', 'Kopf', ',', 'die', 'andere', 'Person', 'auf', 'dem', 'anderen', 'Mann', 'in', 'die', 'Luft', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.5570
# ['<sos>', 'Eine', 'Frau', 'in', 'einer', 'schwarzen', 'Jacke', 'steht', 'vor', 'einer', 'roten', 'Jacke', '.', '<eos>']
# [+] Epoch: [4/10] Loss: 1.5809
# ['<sos>', 'Zwei', 'junge', 'Erwachsene', 'fahren', 'eine', 'Straße', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4413
# ['<sos>', 'Mehrere', 'Personen', 'gehen', 'durch', 'eine', 'belebte', 'Straße', 'entlang', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.3839
# ['<sos>', 'Viele', 'Leute', 'gehen', 'im', 'Hintergrund', 'sind', 'im', 'Hintergrund', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4908
# ['<sos>', 'Ein', 'Mann', 'und', 'eine', 'Frau', 'sitzen', 'neben', 'einem', 'Mann', 'und', 'eine', 'Frau', 'mit', 'einem', 'Mann', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4619
# ['<sos>', 'Ein', 'Mann', 'und', 'eine', 'Frau', 'stehen', 'draußen', 'und', 'eine', 'Frau', 'mit', 'einem', 'Wagen', 'mit', 'einem', 'Gebäude', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4477
# ['<sos>', 'Frauen', 'gehen', 'auf', 'dem', 'Kopf', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4499
# ['<sos>', 'Vier', 'Personen', 'in', 'einer', 'Straßenecke', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4881
# ['<sos>', 'Männer', 'stehen', 'neben', 'einem', 'Auto', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4988
# ['<sos>', 'Zwei', 'Kinder', 'fahren', 'auf', 'einem', 'verschneiten', 'Hang', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4572
# ['<sos>', 'Eine', 'Gruppe', 'von', 'Personen', 'versammelt', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4444
# ['<sos>', 'Ein', 'Mann', 'mit', 'Jeans', 'geht', 'mit', 'einem', 'Rucksack', 'und', 'Jeans', 'und', 'mit', 'Jeans', 'und', 'Jeans', 'geht', 'mit', 'einem', 'schwarzen', 'Jeans', 'und', 'trägt', ',', 'geht', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4690
# ['<sos>', 'Ein', 'Mann', 'mit', 'blauen', 'Schürze', 'bereitet', 'sich', 'in', 'einem', 'blauen', 'Pullover', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.6141
# ['<sos>', 'Viele', 'Personen', 'sitzen', 'in', 'einem', 'Restaurant', 'in', 'einem', 'Restaurant', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.5009
# ['<sos>', 'Eine', 'Gruppe', 'von', 'Menschen', 'spielt', 'in', 'einem', 'Waldgebiet', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.5066
# ['<sos>', 'Mädchen', 'steht', 'auf', 'dem', 'Boden', '.', '<eos>']
# [+] Epoch: [5/10] Loss: 1.4937
# ['<sos>', 'Eine', 'Frau', 'sitzt', 'an', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.4310
# ['<sos>', 'Ein', 'Mann', 'spielt', 'Gitarre', 'spielt', 'auf', 'einer', 'Bühne', ',', 'während', 'andere', 'Frau', 'spielt', 'Gitarre', 'spielt', 'Gitarre', 'spielt', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.2792
# ['<sos>', 'Ein', 'Mann', 'mit', 'blauer', 'Kappe', 'und', 'blauer', 'Kappe', 'macht', 'ein', 'Foto', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.2869
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'blauen', 'Hosen', 'und', 'blauer', 'Krawatte', 'und', 'hält', 'eine', 'blaue', 'Hose', 'steht', 'vor', 'einem', 'großen', 'Gebäude', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3212
# ['<sos>', 'Ein', 'Mann', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3267
# ['<sos>', 'Drei', 'weiß', 'gekleidete', 'Frauen', 'gehen', 'auf', 'einem', 'orangefarbenen', 'Westen', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3786
# ['<sos>', 'Ein', 'Spielmannszug', 'in', 'der', 'Hand', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3008
# ['<sos>', 'Eine', 'Gruppe', 'älterer', 'Personen', 'stehen', 'vor', 'einer', 'Gruppe', 'von', 'Menschen', 'steht', 'in', 'einer', 'Reihe', 'und', 'drei', 'Personen', ',', 'die', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3949
# ['<sos>', 'Ein', 'Mädchen', 'in', 'einem', 'roten', 'Trikot', ',', 'blau', 'gekleidetes', 'Mädchen', 'spielt', 'Fußball', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3587
# ['<sos>', 'Eine', 'Menschenmenge', 'wartet', 'auf', 'ein', 'Publikum', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.4002
# ['<sos>', 'Eine', 'Frau', 'in', 'einem', 'schwarzen', 'Hemd', ',', 'die', 'an', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3104
# ['<sos>', 'Ein', 'alter', 'Mann', 'mit', 'Brille', 'geht', 'an', 'einem', 'Gebäude', 'vorbei', ',', 'während', 'er', 'an', 'einem', 'Gebäude', ',', 'der', 'ein', 'Gebäude', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3795
# ['<sos>', 'Kinder', 'in', 'T-Shirts', 'stehen', 'auf', 'einer', 'Veranda', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3471
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'schwarzen', 'Hemd', 'spielt', 'Gitarre', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3507
# ['<sos>', 'Ein', 'brauner', 'Hund', 'springt', 'in', 'die', 'Luft', '.', '<eos>']
# [+] Epoch: [6/10] Loss: 1.3075
# ['<sos>', 'Eine', 'Frau', 'mit', 'weißem', 'Hemd', 'und', 'einem', 'weißen', 'Mauer', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.1872
# ['<sos>', 'Diese', 'Frau', 'spielt', 'ein', 'Instrument', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.1550
# ['<sos>', 'Eine', 'Person', 'mit', 'einem', 'rosa', 'Wasser', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2299
# ['<sos>', 'Eine', 'rothaarige', 'Frau', 'mit', 'roten', 'Haaren', 'hält', 'zwei', 'roten', 'Haaren', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.1918
# ['<sos>', 'Ein', 'Rennauto', 'fährt', 'durch', 'die', 'Luft', ',', 'während', 'Zuschauer', 'zusehen', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2241
# ['<sos>', 'Ein', 'Mann', 'reitet', 'auf', 'einem', 'Umzug', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2065
# ['<sos>', 'Kinder', 'spielen', 'auf', 'dem', 'Gehweg', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2550
# ['<sos>', 'Ein', 'junges', 'Mädchen', 'in', 'einem', 'rosa', 'und', 'andere', 'Person', 'blickt', 'nach', 'vorn', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2779
# ['<sos>', 'Vier', 'Teenager', 'sitzen', 'nachts', 'auf', 'einer', 'Bank', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2123
# ['<sos>', 'Eine', 'Gruppe', 'von', 'Männern', 'steht', 'in', 'einem', 'Basketball', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2658
# ['<sos>', 'Ein', 'kleines', 'Mädchen', ',', 'das', 'einen', 'rosafarbenen', 'Oberteil', 'fährt', 'ein', 'Fahrrad', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2437
# ['<sos>', 'Ein', 'Kind', 'in', 'einer', 'grünen', 'Jacke', 'wirft', 'einen', 'grünen', 'Jacke', ',', 'der', 'Bowlingbahn', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.3386
# ['<sos>', 'Ein', 'Mann', 'mit', 'einer', 'Menschenmenge', 'ein', 'Mann', 'mit', 'einem', 'Stadion', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.1861
# ['<sos>', 'Vier', 'junge', 'Männer', 'und', 'zwei', 'Männer', 'und', 'ein', 'Gericht', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2561
# ['<sos>', 'Ein', 'Mann', 'auf', 'einer', 'Frau', 'versucht', ',', 'der', 'Treppe', 'auf', 'einem', 'Parkplatz', 'und', 'auf', 'der', 'Erde', 'zu', 'fangen', '.', '<eos>']
# [+] Epoch: [7/10] Loss: 1.2748
# ['<sos>', 'Eine', 'Frau', 'mit', 'roten', 'Haaren', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1333
# ['<sos>', 'Zwei', 'Männer', 'schauen', 'zu', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1297
# ['<sos>', 'Ein', 'braun-schwarzer', 'Hund', 'rennt', 'im', 'Schnee', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.0517
# ['<sos>', 'Eine', 'Frau', 'geht', 'auf', 'dem', 'Gehweg', 'neben', 'einer', 'Menschenmenge', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.0821
# ['<sos>', 'Kinder', 'und', 'um', 'sich', 'um', 'sie', 'sich', 'darauf', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1095
# ['<sos>', 'Zwei', 'Mädchen', 'pflücken', 'Mann', 'an', 'einem', 'gelben', 'Blumen', 'an', 'einem', 'sonnigen', 'Tag', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1357
# ['<sos>', 'Ein', 'schwarz', 'gekleideter', 'Junge', 'hinter', 'ihm', 'sind', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1246
# ['<sos>', 'Ein', 'Mädchen', 'fährt', 'an', 'einem', 'Gewässer', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1017
# ['<sos>', 'Ein', 'grüner', 'Autos', ',', 'dass', 'der', 'Straße', 'wartet', 'auf', 'die', 'grün', 'überquert', 'die', 'Straße', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1933
# ['<sos>', 'Ein', 'kleines', 'Mädchen', 'mit', 'blonden', 'Haaren', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1505
# ['<sos>', 'Zwei', 'Männer', 'bauen', 'eine', 'Mahlzeit', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1136
# ['<sos>', 'Ein', 'kleines', 'Mädchen', 'hält', 'eine', 'Kamera', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.0969
# ['<sos>', 'Drei', 'Männer', 'sitzen', 'an', 'einem', 'Tisch', 'und', 'trinken', 'Bier', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1135
# ['<sos>', 'Eine', 'ältere', 'Frau', 'schaut', 'auf', 'einer', 'Tasche', 'anschaut', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1796
# ['<sos>', 'Drei', 'Personen', 'sitzen', 'an', 'einem', 'Tisch', '.', '<eos>']
# [+] Epoch: [8/10] Loss: 1.1560
# ['<sos>', 'Ein', 'Skateboarder', 'Skateboardfahrer', 'blickt', 'in', 'die', 'Ferne', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 0.9887
# ['<sos>', 'Eine', 'Frau', 'und', 'ein', 'Kind', 'sitzen', 'zusammen', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 0.9708
# ['<sos>', 'Eine', 'Gruppe', 'Männer', 'steht', 'an', 'einem', 'Schaufenster', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 0.9872
# ['<sos>', 'Ein', 'kleines', 'Mädchen', 'steht', 'am', 'Strand', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 0.9894
# ['<sos>', 'Eine', 'große', 'Gruppe', 'von', 'Menschen', 'läuft', 'auf', 'einer', 'großen', 'Eisherz', 'für', 'eine', 'große', 'Anzahl', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0667
# ['<sos>', 'Ein', 'Mann', 'mit', 'orangefarbenem', 'Overall', 'arbeitet', 'mit', 'einem', 'Eisenbahnfahrzeug', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0238
# ['<sos>', 'Ein', 'Mann', 'mittleren', 'Alters', ',', 'der', 'in', 'einem', 'Restaurant', 'und', 'liest', 'in', 'einem', 'Kaffee', 'in', 'einem', 'Park', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0520
# ['<sos>', 'Kinder', 'in', 'einem', 'Rennen', 'im', 'Freien', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0456
# ['<sos>', 'Ein', 'Fußballspieler', 'schießt', 'mit', 'einem', 'Ball', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.1243
# ['<sos>', 'Eine', 'Menschenmenge', 'geht', 'auf', 'dem', 'Gehweg', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0541
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'Motorrad', ',', 'während', 'ein', 'anderer', 'Mann', 'hinter', 'ihm', 'steht', ',', 'während', 'ein', 'anderer', 'Mann', 'in', 'der', 'Luft', ',', 'während', 'ein', 'anderer', 'Mann', 'steht', 'hinter', 'ihm', '.']
# [+] Epoch: [9/10] Loss: 1.0568
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'blauen', 'Hemd', ',', 'der', 'in', 'einem', 'Boot', 'auf', 'einem', 'Grill', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0878
# ['<sos>', 'Zwei', 'Kinder', 'in', 'einem', 'blauen', 'Overalls', 'und', 'blauen', 'blauen', 'und', 'einer', 'blauen', 'und', 'einer', 'blauen', 'Kamera', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0714
# ['<sos>', 'Drei', 'kleine', 'Kinder', ',', 'die', 'am', 'Strand', ',', 'das', 'Wasser', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0493
# ['<sos>', 'Eine', 'Frau', 'in', 'einem', 'schwarzen', 'Rock', 'geht', 'eine', 'Straße', 'herunter', 'und', 'Rock', 'geht', 'die', 'Straße', 'herunter', '.', '<eos>']
# [+] Epoch: [9/10] Loss: 1.0554
# ['<sos>', 'Ein', 'erwachsenes', 'Paar', 'genießt', 'das', 'Schwimmbecken', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9028
# ['<sos>', 'Ein', 'Mann', 'fährt', 'in', 'der', 'Luft', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9467
# ['<sos>', 'Ein', 'älterer', 'Mann', 'mit', 'Bart', 'in', 'einem', 'Spiegel', 'einem', 'baufälligen', 'Gebäude', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9099
# ['<sos>', 'Der', 'Mann', 'in', 'roter', 'Kleidung', 'steht', 'auf', 'dem', 'Bürgersteig', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.8988
# ['<sos>', 'Ein', 'kleines', 'Mädchen', 'hält', 'das', 'Wasser', 'aus', ',', 'um', 'das', 'Mädchen', 'aus', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9056
# ['<sos>', 'Ein', 'Bowlingspieler', 'hat', 'gerade', 'eine', 'Bowlingkugel', 'in', 'Richtung', 'der', 'Bowlingbahn', ',', 'dass', 'die', 'Straße', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9709
# ['<sos>', 'Ein', 'Footballspieler', 'springt', 'über', 'die', 'Luft', 'fliegenden', 'Tor', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9644
# ['<sos>', 'Ein', 'weißer', 'Hund', 'mit', 'Halsband', 'und', 'Leine', 'gehalten', 'mit', 'einem', 'Stock', 'in', 'der', 'Leine', 'und', 'mit', 'dem', 'Bürgersteig', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 1.0080
# ['<sos>', 'Eine', 'Frau', 'mit', 'ihrem', 'Hund', 'mit', 'ihrem', 'Einkaufsbummel', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9639
# ['<sos>', 'Afroamerikanische', 'Leute', 'gehen', 'an', 'einem', 'Gebäude', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9983
# ['<sos>', 'Ich', 'glaube', ',', 'bei', 'einem', 'erleuchteten', 'Keller', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 1.0058
# ['<sos>', 'Eine', 'Gruppe', 'steht', 'vor', 'einem', 'Zug', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 1.0012
# ['<sos>', 'Ein', 'Herr', 'in', 'einem', 'rosa', 'Oberteil', 'steht', ',', 'während', 'ein', 'Publikum', 'zuschaut', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9769
# ['<sos>', 'Ein', 'Junge', 'in', 'einem', 'grünen', 'Hemd', 'sitzt', 'auf', 'einem', 'Stuhl', 'und', 'in', 'einem', 'grünen', 'Boot', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9868
# ['<sos>', 'Eine', 'Person', 'mit', 'Schneeschuhen', 'fährt', 'mit', 'einem', 'schneebedeckten', 'Hügel', '.', '<eos>']
# [+] Epoch: [10/10] Loss: 0.9709
# ['<sos>', 'Zwei', 'Kerle', 'in', 'einem', 'Raum', '.', '<eos>']

# %% [markdown]
# #輸出測試結果

# %%
model = Seq2Seq(src_vocab_len, dst_vocab_len, hidden_size, num_layer)
if torch.cuda.device_count() > 0:
  model = model.cuda()
model.load_state_dict(torch.load("/content/drive/MyDrive/PythonProject/TranslationZero/seq2seq_modelv2.pth"))
model = model.eval()

for iters, data in enumerate(test_set, 0):
  src_inputs = data.src.long()
  dst_inputs = data.trg.long()
  if torch.cuda.device_count() > 0:
    src_inputs = src_inputs.cuda()
    dst_inputs = dst_inputs.cuda()
  for i in range(10):
    orgin = []
    raw = src_inputs[:, i].tolist()
    
    for index in raw:
      if src_vocab.itos[index] == "<eos>":
        orgin.append(src_vocab.itos[index])
        break
      else:
        orgin.append(src_vocab.itos[index])

    result = model.prediction(src_inputs[:, i].unsqueeze(1), dst_vocab, seq_len)
    print("English=")
    print(orgin)
    print("German=")
    print(result)
    print()
# Out:
# English=
# ['<sos>', 'People', 'are', 'walking', 'on', 'a', 'paved', 'slope', 'surrounded', 'by', 'Chinese', 'vendors', '.', '<eos>']
# German=
# ['<sos>', 'Leute', 'gehen', 'auf', 'einem', 'Feld', 'mit', 'vielen', 'Bäumen', 'gesäumten', 'Weg', '.', '<eos>']
#
# English=
# ['<sos>', 'Five', 'people', 'wearing', 'winter', 'jackets', 'and', 'helmets', 'stand', 'in', 'the', 'snow', ',', 'with', 'snowmobiles', 'in', 'the', 'background', '.', '<eos>']
# German=
# ['<sos>', 'Fünf', 'Personen', 'mit', 'Rucksäcken', 'und', 'stehen', 'im', 'Hintergrund', 'stehen', 'im', 'Hintergrund', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'guy', 'wearing', 'a', 'white', 'shirt', 'is', 'playing', 'a', 'white', 'guitar', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'in', 'weißem', 'Hemd', 'spielt', 'Gitarre', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'young', 'boy', 'in', 'a', 'soccer', 'uniform', 'crying', 'into', 'his', 'palms', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Junge', 'in', 'Uniform', 'wirft', 'einen', 'Baseball', 'in', 'einem', 'Trampolin', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'black', 'and', 'white', 'dog', 'is', 'playing', 'with', 'a', 'white', 'ball', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'schwarz-weißer', 'Hund', 'spielt', 'mit', 'einem', 'weißen', 'Ball', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'boy', 'in', 'a', 'black', 'shirt', 'and', 'red', 'wristbands', 'hanging', 'upside', 'down', 'while', 'other', 'people', 'look', 'on', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Junge', 'in', 'einem', 'schwarzen', 'T-Shirt', 'schaut', 'auf', 'einem', 'anderen', 'Leuten', 'zuschauen', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'blond', 'girl', 'sleeps', 'on', 'a', 'brown', 'couch', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'blondes', 'Mädchen', 'schläft', 'auf', 'einem', 'braunen', 'Sofa', '.', '<eos>']
#
# English=
# ['<sos>', 'Four', 'females', 'of', 'Asian', 'descent', 'are', 'wearing', 'golden', 'dresses', 'while', 'performing', 'point', 'ballet', '.', '<eos>']
# German=
# ['<sos>', 'Vier', 'asiatische', 'Frauen', 'in', 'traditionellen', 'Tanz', 'auf', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'cat', 'sits', 'on', 'top', 'of', 'a', 'store', 'sign', '.', '<eos>']
# German=
# ['<sos>', 'Eine', 'Katze', 'sitzt', 'auf', 'einem', 'Schild', '.', '<eos>']
#
# English=
# ['<sos>', 'Woman', 'and', 'dog', 'selling', 'her', 'wares', 'on', 'the', 'old', 'building', 'steps', 'outside', '.', '<eos>']
# German=
# ['<sos>', 'Eine', 'Frau', 'und', 'verkauft', 'auf', 'dem', 'Bürgersteig', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'children', ',', 'a', 'boy', 'in', 'a', 'yellow', 'shirt', 'and', 'a', 'girl', 'in', 'blue', 'and', 'white', 'stripes', ',', 'swinging', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Junge', 'und', 'ein', 'Junge', 'und', 'ein', 'Junge', 'und', 'gelben', 'und', 'ein', 'Mädchen', 'in', 'einem', 'Bett', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'teenager', 'plays', 'her', 'trumpet', 'on', 'the', 'field', 'at', 'a', 'game', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Teenager', 'spielt', 'auf', 'dem', 'Boden', 'und', 'spielt', 'auf', 'dem', 'Spiel', 'auf', 'dem', 'Feld', '.', '<eos>']
#
# English=
# ['<sos>', 'An', 'old', 'man', 'on', 'a', 'subway', 'wearing', 'heavy', 'layered', 'clothing', 'is', 'reading', 'a', 'newspaper', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'alter', 'Mann', 'in', 'einem', 'U-Bahn', 'liest', 'im', 'Waschsalon', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'young', 'child', 'sleeping', 'in', 'her', 'bed', 'with', 'an', 'open', 'book', 'on', 'her', 'chest', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'kleines', 'Kind', 'schläft', 'mit', 'ihrem', 'Schoß', 'eines', 'kleinen', 'Gegenstand', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'black', 'dogs', ',', 'a', 'black', 'puppy', ',', 'and', 'a', 'white', 'dog', 'in', 'the', 'snow', '.', '<eos>']
# German=
# ['<sos>', 'Zwei', 'schwarze', 'und', 'ein', 'schwarzer', 'Hund', 'im', 'Schnee', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'mother', 'teaches', 'her', 'two', 'young', 'boys', 'to', 'fish', 'off', 'of', 'a', 'rocky', 'coast', 'into', 'very', 'blue', 'water', '.', '<eos>']
# German=
# ['<sos>', 'Eine', 'kleine', 'Jungen', 'von', 'zwei', 'Jungen', 'taucht', ',', 'um', 'einen', 'langen', 'Griff', ',', 'das', 'Meer', ',', 'das', 'Wasser', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'talking', 'to', 'a', 'family', 'unit', 'holding', 'some', 'sort', 'of', 'probing', 'device', 'as', 'they', 'look', 'on', 'and', 'smile', 'to', 'be', 'polite', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'hält', 'ein', 'Mann', 'und', 'halten', '.', '<eos>']
#
# English=
# ['<sos>', 'This', 'lady', 'has', 'heard', 'a', 'funny', 'joke', 'and', 'laughing', '.', '<eos>']
# German=
# ['<sos>', 'Diese', 'Dame', 'lacht', 'und', 'lacht', 'und', 'lacht', 'und', 'eine', 'Frau', 'lacht', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'young', 'boy', 'jumping', 'from', 'a', 'bunk', 'bed', 'on', 'a', 'smaller', 'bed', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'kleiner', 'Junge', 'springt', 'von', 'einem', 'Bett', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'bald', 'man', 'demonstarting', 'how', 'high', 'his', 'brown', 'and', 'black', 'dog', 'can', 'jump', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'glatzköpfiger', 'Mann', 'und', 'ein', 'schwarzer', 'Hund', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'lounges', 'on', 'a', 'red', 'sofa', 'in', 'a', 'furniture', 'showroom', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'roten', 'Hut', 'auf', 'einem', 'roten', 'Hut', 'auf', 'einem', 'Möbelstück', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'teacher', 'in', 'white', 'and', 'a', 'little', 'girl', 'wearing', 'a', 'yellow', 'dress', 'playing', 'with', 'building', 'block', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'kleines', 'Mädchen', 'in', 'einem', 'weißen', 'Kleid', 'mit', 'einem', 'gelben', 'Gebäude', 'mit', 'einem', 'Gebäude', 'mit', 'einem', 'weißen', 'Gebäude', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'children', 'looking', 'at', 'horses', 'through', 'a', 'small', 'fence', '.', '<eos>']
# German=
# ['<sos>', 'Zwei', 'kleine', 'Kinder', 'schauen', 'über', 'einen', 'Zaun', 'und', 'schauen', 'durch', '.', '<eos>']
#
# English=
# ['<sos>', 'The', 'red', 'car', 'is', 'ahead', 'of', 'the', 'two', 'cars', 'in', 'the', 'background', '.', '<eos>']
# German=
# ['<sos>', 'Der', 'Auto', 'mit', 'dem', 'Auto', 'mit', 'dem', 'Auto', 'mit', 'dem', 'Auto', 'parkt', '.', '<eos>']
#
# English=
# ['<sos>', 'An', 'Asian', 'woman', 'in', 'a', 'floral', 'wedding', 'dress', 'poses', 'on', 'a', 'bridge', 'close', 'to', 'her', 'bridesmaids', '.', '<eos>']
# German=
# ['<sos>', 'Eine', 'asiatische', 'Frau', 'in', 'einem', 'Kleid', 'posiert', 'auf', 'einer', 'Picknickbank', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'boy', 'with', 'a', 'bruised', 'nose', 'and', 'writing', 'on', 'his', 'hands', 'is', 'standing', 'in', 'a', 'video', 'rental', 'store', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Junge', 'steht', 'mit', 'einem', 'Waschbecken', 'und', 'einem', 'Hammer', 'auf', 'seinem', 'Händen', 'und', 'hält', 'einen', 'Hammer', 'und', 'steht', 'mit', 'einem', 'Waschbecken', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'in', 'a', 'red', 'shirt', 'is', 'about', 'to', 'eat', 'a', 'taco', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'roten', 'Hemd', 'ist', 'rot', 'gekleideten', 'Mann', 'zu', '.', '<eos>']
#
# English=
# ['<sos>', 'An', 'overweight', 'woman', 'with', 'long', 'black', 'hair', 'in', 'a', 'pink', 'shirt', 'with', 'a', 'name', 'tag', 'is', 'applying', 'lipstick', '.', '<eos>']
# German=
# ['<sos>', 'Eine', 'übergewichtige', 'schwarze', 'Frau', 'in', 'einem', 'schwarzen', 'Haaren', 'in', 'einem', 'schwarzen', 'Haaren', ',', 'die', 'Haare', '.', '<eos>']
#
# English=
# ['<sos>', 'Parked', 'cars', 'with', 'a', 'school', 'bus', 'behind', 'them', '.', '<eos>']
# German=
# ['<sos>', 'Autos', 'abgestellt', '.', '<eos>']
#
# English=
# ['<sos>', 'An', 'older', 'woman', 'and', 'a', 'young', 'child', 'in', 'a', 'pink', 'shirt', 'playing', 'with', 'multicolored', 'blocks', '.', '<eos>']
# German=
# ['<sos>', 'Eine', 'ältere', 'Frau', 'in', 'einem', 'rosa', 'gekleidete', 'Frau', 'in', 'einem', 'rosafarbenen', 'Oberteil', 'spielt', 'mit', 'einem', 'Hula-Hoop-Reifen', '.', '<eos>']
#
# English=
# ['<sos>', 'An', 'African', 'American', 'man', 'walking', 'down', 'the', 'street', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Afroamerikaner', 'geht', 'eine', 'Straße', 'entlang', '.', '<eos>']
#
# English=
# ['<sos>', 'Outside', 'a', 'building', ',', 'a', 'uniformed', 'security', 'guard', 'looks', 'at', 'the', 'camera', 'from', 'behind', 'a', 'fence', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'hinter', 'einem', 'Zaun', 'und', 'bunt', 'gekleidete', 'Menschen', 'hinter', 'einem', 'Zaun', ',', 'während', 'hinter', 'einem', 'Zaun', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'group', 'of', 'people', 'on', 'the', 'street', 'setting', 'up', 'instruments', '.', '<eos>']
# German=
# ['<sos>', 'Eine', 'Gruppe', 'von', 'Menschen', 'auf', 'der', 'Straße', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'in', 'uniform', 'and', 'a', 'man', 'in', 'a', 'blue', 'shirt', 'are', 'standing', 'in', 'front', 'of', 'a', 'truck', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'Lkw', 'und', 'steht', 'in', 'einem', 'blauen', 'Hemd', 'und', 'einem', 'Lastwagen', '.', '<eos>']
#
# English=
# ['<sos>', 'Four', 'men', 'are', 'outside', 'looking', 'down', 'over', 'the', 'green', 'bridge', 'they', 'are', 'on', '.', '<eos>']
# German=
# ['<sos>', 'Vier', 'Männer', 'schauen', 'auf', 'der', 'offenen', 'grünen', 'Brücke', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'men', 'sit', 'talking', 'near', 'a', 'stone', 'building', '.', '<eos>']
# German=
# ['<sos>', 'Zwei', 'Männer', 'sitzen', 'in', 'der', 'Nähe', 'eines', 'Gebäudes', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'in', 'a', 'yellow', 'shirt', 'and', 'a', 'man', 'in', 'a', 'dark', 'blue', 'shirt', 'talking', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'gelben', 'Hemd', 'spricht', 'in', 'einem', 'gelben', 'Hemd', 'spricht', 'in', 'einem', 'gelben', 'Hemd', 'spricht', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'young', 'girl', 'standing', 'next', 'to', 'a', 'yellow', 'cat', 'on', 'a', 'kitchen', 'countertop', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'junges', 'Mädchen', 'steht', 'neben', 'einer', 'gelben', 'Jacke', 'steht', 'neben', 'einer', 'gelben', 'Ballon', 'in', 'einer', 'Straße', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'brown', 'dogs', 'playing', 'in', 'a', 'rough', 'manner', '.', '<eos>']
# German=
# ['<sos>', 'Zwei', 'braune', 'Hunde', 'spielen', 'in', 'einem', 'braunen', 'Hunde', 'spielen', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'long', '-', 'haired', ',', 'male', 'musician', 'is', 'playing', 'on', 'a', 'piano', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'langhaariger', 'Mann', 'spielt', 'Klavier', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'girl', 'in', 'a', 'jean', 'dress', 'is', 'walking', 'along', 'a', 'raised', 'balance', 'beam', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mädchen', 'in', 'einem', 'Kleid', 'geht', 'durch', 'eine', 'Fußgängerbrücke', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'young', 'men', 'on', 'opposing', 'soccer', 'teams', 'are', 'competing', 'to', 'get', 'the', 'ball', 'on', 'a', 'soccer', 'field', '.', '<eos>']
# German=
# ['<sos>', 'Zwei', 'junge', 'Männer', 'rennen', 'auf', 'dem', 'Fußballfeld', 'werden', 'auf', 'dem', 'Feld', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'advertises', 'with', 'a', 'giant', 'sign', 'tied', 'onto', 'his', 'bicycle', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'mit', 'einem', 'Schild', 'mit', 'einem', 'Schild', 'mit', 'einem', 'Fahrrad', 'mit', 'einem', 'Assistenztrainer', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'dog', 'is', 'jumping', 'through', 'a', 'fiery', 'obstacle', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Hund', 'springt', 'über', 'einen', 'Hindernispfad', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'in', 'a', 'black', 'shirt', 'fishing', 'on', 'a', 'rocky', 'shore', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'in', 'einem', 'felsigen', 'Strand', '.', '<eos>']
#
# English=
# ['<sos>', 'Three', 'woman', 'bouncing', 'on', 'balls', 'in', 'the', 'grass', '.', '<eos>']
# German=
# ['<sos>', 'Drei', 'Frauen', 'springen', 'auf', 'dem', 'Gras', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'nuns', 'are', 'posing', 'for', 'a', 'picture', '.', '<eos>']
# German=
# ['<sos>', 'Zwei', 'Feuerwehrmänner', 'posieren', 'für', 'ein', 'Foto', '.', '<eos>']
#
# English=
# ['<sos>', 'Two', 'men', 'and', 'a', 'lady', 'are', 'standing', 'outside', '.', '<eos>']
# German=
# ['<sos>', 'Zwei', 'Männer', 'stehen', 'draußen', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'playing', 'an', 'instrument', 'next', 'to', 'a', 'tree', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'spielt', 'neben', 'einem', 'Baum', ',', 'der', 'Nähe', 'eines', 'Instrument', '.', '<eos>']
#
# English=
# ['<sos>', 'A', 'man', 'in', 'a', 'black', 'jacket', 'plays', 'the', 'guitar', 'out', 'in', 'public', '.', '<eos>']
# German=
# ['<sos>', 'Ein', 'Mann', 'in', 'einer', 'schwarzen', 'Lederjacke', 'spielt', 'Gitarre', '.', '<eos>']

# %% [markdown]
# # 自訂翻譯結果

# %%
model = Seq2Seq(src_vocab_len, dst_vocab_len, hidden_size, num_layer)
if torch.cuda.device_count() > 0:
  model = model.cuda()
model.load_state_dict(torch.load("/content/drive/MyDrive/PythonProject/TranslationZero/seq2seq_modelv2.pth"))
model = model.eval()

inputs_list = []

inputs_list.append(src_vocab.stoi['<sos>'])
data = str(input("Input:"))
for word in data.split(' '):
  inputs_list.append(src_vocab.stoi[word])
inputs_list.append(src_vocab.stoi['<eos>'])

while len(inputs_list) < seq_len:
  inputs_list.append(src_vocab.stoi['<pad>'])

inputs_list = inputs_list[:seq_len]

inputs = torch.from_numpy(numpy.array([inputs_list])).permute(1, 0).long()
inputs = inputs.cuda()
outputs = model.prediction(inputs, dst_vocab, seq_len)
print(outputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a593b6344e19> in <module>()
# ----> 1 model = Seq2Seq(src_vocab_len, dst_vocab_len, hidden_size, num_layer)
#       2 if torch.cuda.device_count() > 0:
#       3   model = model.cuda()
#       4 model.load_state_dict(torch.load("/content/drive/MyDrive/PythonProject/TranslationZero/seq2seq_modelv2.pth"))
#       5 model = model.eval()
#
# NameError: name 'Seq2Seq' is not defined
